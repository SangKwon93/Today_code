# %%
import pandas as pd

# %%
file='C:/Users/psk/3rd_backup/kream_detail_pro8.csv'

# %%
df = pd.read_csv(file)
df
# Out:
#                                                     _id     brand  \
# 0                             Jordan 1 Low Vintage Grey   Jordan
# 1     Jordan 1 x Travis Scott x Fragment Retro Low O...   Jordan
# 2                    Jordan 1 Retro High OG Black Mocha   Jordan
# 3                        Jordan 4 Retro White and Black   Jordan
# 4                 Jordan 1 Retro High OG Bleached Coral   Jordan
# ...                                                 ...       ...
# 2988       Jordan 1 Retro High OG SP Gina (Special Box)   Jordan
# 2989                        Jordan 13 Retro Low Quai 54   Jordan
# 2990                (GS) Jordan 11 Retro Heiress Velvet   Jordan
# 2991    Jordan 1 Retro High Flyknit Derek Jeter RE2PECT   Jordan
# 2992                      (GS) Jordan 1 Retro High Melo   Jordan
#
#                                      prod_kr_name  rescent_price  \
# 0                                 조던 1 로우 빈티지 그레이         200000
# ...

# %%
df.columns
# Out:
# Index(['_id', 'brand', 'prod_kr_name', 'rescent_price', 'model_no',
#        'release_date', 'colors', 'release_price', 'instant_buy_price',
#        'instant_sell_price', 'img_url'],
#       dtype='object')

# %%
df1= df.loc[:,['model_no', 'rescent_price','release_price', 'instant_buy_price','instant_sell_price']]
df1
# Out:
#           model_no  rescent_price  release_price  instant_buy_price  \
# 0      553558-053          200000         129000             202000
# 1      DM7866-140         1555000         189000            1540000
# 2      555088-105          702000         199000             600000
# 3      DH6927-111          312000         249000             299000
# 4      555088-108          244000         209000             207000
# ...            ...            ...            ...                ...
# 2988   CD7071-001               0         234600                  0
# 2989   810551-050               0         325200                  0
# 2990   852625-650          290000         286200             340000
# 2991   AH7233-105          350000         234100             380000
# 2992   705300-026          229000         143100             299000
#
#       instant_sell_price
# 0                 201000
# 1                2230000
# 2                 818000
# 3                 313000
# ...

# %%
def strip_pro(data):
    data = data.strip()
    return data

# %%
df1['model_no']= df1['model_no'].apply(strip_pro)
df1
# Out:
#         model_no  rescent_price  release_price  instant_buy_price  \
# 0     553558-053         200000         129000             202000
# 1     DM7866-140        1555000         189000            1540000
# 2     555088-105         702000         199000             600000
# 3     DH6927-111         312000         249000             299000
# 4     555088-108         244000         209000             207000
# ...          ...            ...            ...                ...
# 2988  CD7071-001              0         234600                  0
# 2989  810551-050              0         325200                  0
# 2990  852625-650         290000         286200             340000
# 2991  AH7233-105         350000         234100             380000
# 2992  705300-026         229000         143100             299000
#
#       instant_sell_price
# 0                 201000
# 1                2230000
# 2                 818000
# 3                 313000
# 4                 270000
# ...

# %%
df1.to_csv('C:/Users/psk/3rd_backup/ERD_table/price_table.csv', index=False, encoding='cp949')
